# %% [markdown]
# <a href="https://colab.research.google.com/github/12sandra/practice_problems_pybasics/blob/main/PRACTICE_EXERCISES_ON_PYTHON_BASICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a Python program which accepts the radius of a circle from the user and compute the area.
# Sample input: Enter the radius: 3
# Sample output: Area of Circle is 28.59999999999
r = float(input("Enter the radius: "))
pi = 22/7
area = pi * r * r
print("Area of Circle is", area)
# Out:
# Enter the radius: 3
# Area of Circle is 28.285714285714285

# %%
# #Write a Python Program to accept the details of a student like name, roll
# number and mark and display it.
# Sample input: Enter the name: Anisha
# Enter the roll number: 21
# Enter the mark: 78
# Sample output: Name: Anisha
# Roll No: 21
# Mark: 78
name = input("Enter the name: ")
roll = input("Enter the roll number: ")
mark = input("Enter the mark: ")

print("Name:", name)
print("Roll No:", roll)
print("Mark:", mark)
# Out:
# Enter the name: Aji
# Enter the roll number: 67
# Enter the mark: 78
# Name: Aji
# Roll No: 67
# Mark: 78

# %%
# #Write a Python program to get the largest number from a list.
# Sample input: 12, 3, 47, 10
# Sample output: 47 is the largest number
numbers = [12, 3, 47, 10]

largest = numbers[0]

for num in numbers:
    if num > largest:
        largest = num

print(largest, "is the largest number")
# Out:
# 47 is the largest number

# %%
#

previous = 0

for current in range(1, 11):
    total = current + previous
    print("Current Number", current, "Previous Number", previous, "Sum:", total)
    previous = current
# Out:
# Current Number 1 Previous Number 0 Sum: 1
# Current Number 2 Previous Number 1 Sum: 3
# Current Number 3 Previous Number 2 Sum: 5
# Current Number 4 Previous Number 3 Sum: 7
# Current Number 5 Previous Number 4 Sum: 9
# Current Number 6 Previous Number 5 Sum: 11
# Current Number 7 Previous Number 6 Sum: 13
# Current Number 8 Previous Number 7 Sum: 15
# Current Number 9 Previous Number 8 Sum: 17
# Current Number 10 Previous Number 9 Sum: 19

# %%
# Write a Python program to print only those numbers which are divisible of 5.
# Sample input: 10, 20,33,46,55 Sample output: 10, 20, 55

numbers = [10, 20, 33, 46, 55]

for n in numbers:
    if n % 5 == 0:
        print(n)
# Out:
# 10
# 20
# 55

# %%
# Write a Python program to check whether a number is prime or not. Sample input: Enter the number: 3
# Sample output: 3 is a prime number.

num = int(input("Enter the number: "))

if num <= 1:
    print(num, "is not a prime number.")
else:
    for i in range(2, num):
        if num % i == 0:
            print(num, "is not a prime number.")
            break
    else:
        print(num, "is a prime number.")
# Out:
# Enter the number: 3
# 3 is a prime number.

# %%
# #Write a Python program to reverse a list using for loop.
# Sample input: 10,40,30,70
# Sample output: 70,30,40,10

lst = [10, 40, 30, 70]

reversed_list = lst[::-1]

print(reversed_list)
# Out:
# [70, 30, 40, 10]

# %%
#pattern
for i in range(1, 5):
    print("*" * i)
# Out:
# *
# **
# ***
# ****

# %%
# Write a Python program to find the maximum of three numbers
# Sample input: 34,12,7

# Sample output: 34
a = 34
b = 12
c = 7

if a >= b and a >= c:
    print(a)
elif b >= a and b >= c:
    print(b)
else:
    print(c)
# Out:
# 34

# %%
# Write a Python program to construct the following pattern, using a nested for loop.
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *


for i in range(1, 6):
    for j in range(i):
        print("*", end="")
    print()
for i in range(4, 0, -1):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
