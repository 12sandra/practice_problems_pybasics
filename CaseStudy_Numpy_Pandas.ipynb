# %% [markdown]
# <a href="https://colab.research.google.com/github/12sandra/practice_problems_pybasics/blob/main/CaseStudy_Numpy_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1) Import pandas, numpy
import numpy as np
import pandas as pd

# %%
#Load dataset using pd.read_csv()
df=pd.read_csv("/content/IMDB-Movie-Data.csv")

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# **Display: shape, head, column names, datatypes, missing values**

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# **Check and remove duplicates**

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 5) Rename columns ("Title" > "Movie_Title")

# %%
df.rename(columns={'Title': 'Movie_Title'}, inplace=True)
print(df)
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# **6) Get unique genres**

# %%
df.Genre.unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Crime,Drama,Horror',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Horror', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Horror,Mystery,Thriller',
# ...

# %%
df.Genre.value_counts()
# Out:
# Genre
# Action,Adventure,Sci-Fi     50
# Drama                       48
# Comedy,Drama,Romance        35
# Comedy                      32
# Drama,Romance               31
#                             ..
# Drama,Fantasy,Musical        1
# Adventure,Family             1
# Adventure,Comedy,Fantasy     1
# Drama,Family,Music           1
# Comedy,Family,Fantasy        1
# Name: count, Length: 207, dtype: int64

# %% [markdown]
# **7) Extract number of genres per movie**

# %%
df['no_of_genres']=df['Genre'].str.split(',').str.len()
df
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df[['Movie_Title','Genre','no_of_genres']]
# Out:
#                  Movie_Title                     Genre  no_of_genres
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi             3
# 1                 Prometheus  Adventure,Mystery,Sci-Fi             3
# 2                      Split           Horror,Thriller             2
# 3                       Sing   Animation,Comedy,Family             3
# 4              Suicide Squad  Action,Adventure,Fantasy             3
# ..                       ...                       ...           ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery             3
# 996          Hostel: Part II                    Horror             1
# 997   Step Up 2: The Streets       Drama,Music,Romance             3
# 998             Search Party          Adventure,Comedy             2
# 999               Nine Lives     Comedy,Family,Fantasy             3
#
# [1000 rows x 3 columns]

# %% [markdown]
# ###8)Handle missing values in 'Revenue (Millions)' and 'Metascore

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Movie_Title         1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
#  12  no_of_genres        1000 non-null   int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB

# %%
df['Revenue (Millions)'].fillna(value=df['Revenue (Millions)'].mean(), inplace=True)
#missing values filled with mean
# Out:
# /tmp/ipython-input-307260753.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Revenue (Millions)'].fillna(value=df['Revenue (Millions)'].mean(), inplace=True)

# %%
df['Metascore'].fillna(value=df['Metascore'].median(), inplace=True)
print(df)
#Missing values filled with median
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Movie_Title         1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  1000 non-null   float64
#  11  Metascore           1000 non-null   float64
#  12  no_of_genres        1000 non-null   int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB

# %% [markdown]
# **9) Top 5 movies by Rating**

# %%
sorted_df=df.sort_values(by="Rating",ascending=False)
sorted_df.head()
sorted_df[['Movie_Title','Rating']]
# Out:
#                  Movie_Title  Rating
# 54           The Dark Knight     9.0
# 80                 Inception     8.8
# 117                   Dangal     8.8
# 36              Interstellar     8.6
# 249         The Intouchables     8.6
# ..                       ...     ...
# 968                  Wrecker     3.5
# 647                 Tall Men     3.2
# 871     Dragonball Evolution     2.7
# 42   Don't Fuck in the Woods     2.7
# 829           Disaster Movie     1.9
#
# [1000 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Movie_Title         1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  1000 non-null   float64
#  11  Metascore           1000 non-null   float64
#  12  no_of_genres        1000 non-null   int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Movie_Title         1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  1000 non-null   float64
#  11  Metascore           1000 non-null   float64
#  12  no_of_genres        1000 non-null   int64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 101.7+ KB

# %% [markdown]
#  10) Movies with highest/lowest revenue

# %%
highest_revenue_movie = df.sort_values(by='Revenue (Millions)', ascending=False).head(1)
lowest_revenue_movie = df.sort_values(by='Revenue (Millions)', ascending=True).head(1)
highest_revenue_movie
# Out:
#     Rank                                 Movie_Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore  \
# 50                136     8.1  661608              936.63       81.0
#
#     no_of_genres
# 50             3

# %%
lowest_revenue_movie
# Out:
#      Rank       Movie_Title                 Genre  \
# 231   232  A Kind of Murder  Crime,Drama,Thriller
#
#                                            Description      Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 Actors  Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore  \
# 231                 95     5.2   3305                 0.0       50.0
#
#      no_of_genres
# 231             3

# %% [markdown]
#  11 ) Average rating by Director

# %%
avg_rating_by_director = df.groupby('Director')['Rating'].mean()
print(avg_rating_by_director)
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
#  12) Movies per year

# %%
movies_per_year=df.groupby('Year').size()
print(movies_per_year)
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# dtype: int64

# %% [markdown]
# 13) Movies with rating > 8 & revenue > **100M**

# %%
movie_rev = df[(df['Rating'] > 8.0) & (df['Revenue (Millions)'] > 100.0)]
print(movie_rev[['Movie_Title', 'Rating', 'Revenue (Millions)']])
# Out:
#                                       Movie_Title  Rating  Revenue (Millions)
# 0                         Guardians of the Galaxy     8.1              333.13
# 6                                      La La Land     8.3              151.06
# 36                                   Interstellar     8.6              187.99
# 50     Star Wars: Episode VII - The Force Awakens     8.1              936.63
# 54                                The Dark Knight     9.0              533.32
# 67                             Mad Max: Fury Road     8.1              153.63
# 74                                       Zootopia     8.1              341.26
# 76                                   The Avengers     8.1              623.28
# 77                           Inglourious Basterds     8.3              120.52
# 80                                      Inception     8.8              292.57
# 82                        The Wolf of Wall Street     8.2              116.87
# ...

# %% [markdown]
#  14)Group by Director: avg Rating, Revenue

# %%
director_info= df.groupby('Director').agg(
    Avg_Rating=('Rating', 'mean'),
    Avg_Revenue_Millions=('Revenue (Millions)', 'mean'))

print(director_info)
# Out:
#                      Avg_Rating  Avg_Revenue_Millions
# Director
# Aamir Khan                 8.50              1.200000
# Abdellatif Kechiche        7.80              2.200000
# Adam Leon                  6.50             82.956376
# Adam McKay                 7.00            109.535000
# Adam Shankman              6.30             78.665000
# ...                         ...                   ...
# Xavier Dolan               7.55             43.223188
# Yimou Zhang                6.10             45.130000
# Yorgos Lanthimos           7.20              4.405000
# Zack Snyder                7.04            195.148000
# Zackary Adler              5.10              6.530000
#
# [644 rows x 2 columns]

# %% [markdown]
# 15) Group by Year: count, avg Rating

# %%
year_grp = df.groupby('Year').agg(
    Movie_Count=('Movie_Title', 'count'),
    Avg_Rating=('Rating', 'mean'))

print(year_grp)
# Out:
#       Movie_Count  Avg_Rating
# Year
# 2006           44    7.125000
# 2007           53    7.133962
# 2008           52    6.784615
# 2009           51    6.960784
# 2010           60    6.826667
# 2011           63    6.838095
# 2012           64    6.925000
# 2013           91    6.812088
# 2014           98    6.837755
# 2015          127    6.602362
# 2016          297    6.436700

# %% [markdown]
# 16) Create a new column Profitability:
# a) Revenue divided by Duration
# b) Find top 10 most profitable movies

# %%
df['Profitability'] = df['Revenue (Millions)'] / df['Runtime (Minutes)']
top_10_profit = df.sort_values(by='Profitability', ascending=False).head(10)
print(top_10_profit[['Movie_Title', 'Revenue (Millions)', 'Runtime (Minutes)', 'Profitability']])
# Out:
#                                     Movie_Title  Revenue (Millions)  \
# 50   Star Wars: Episode VII - The Force Awakens              936.63
# 85                               Jurassic World              652.18
# 119                                Finding Dory              486.29
# 87                                       Avatar              760.51
# 76                                 The Avengers              623.28
# 15                      The Secret Life of Pets              368.31
# 688                                 Toy Story 3              414.98
# 12                                    Rogue One              532.17
# 174                                      Frozen              400.74
# 797                             Despicable Me 2              368.05
#
#      Runtime (Minutes)  Profitability
# 50                 136       6.886985
# 85                 124       5.259516
# 119                 97       5.013299
# 87                 162       4.694506
# ...

# %% [markdown]
# 17) Create a column that categorizes movies by rating:
# a) Rating < 6: Poor
# b) 6 ≤ Rating < 7.5: Average
# c) Rating ≥ 7.5: Excellent

# %%
conditions = [ df['Rating'] < 6,
    (df['Rating'] >= 6) & (df['Rating'] < 7.5),
    df['Rating'] >= 7.5]


values = ['Poor', 'Average', 'Excellent']

df['Rating_Category'] = np.select(conditions, values, default='Unknown')

print(df[['Movie_Title', 'Rating', 'Rating_Category']])
# Out:
#                  Movie_Title  Rating Rating_Category
# 0    Guardians of the Galaxy     8.1       Excellent
# 1                 Prometheus     7.0         Average
# 2                      Split     7.3         Average
# 3                       Sing     7.2         Average
# 4              Suicide Squad     6.2         Average
# ..                       ...     ...             ...
# 995     Secret in Their Eyes     6.2         Average
# 996          Hostel: Part II     5.5            Poor
# 997   Step Up 2: The Streets     6.2         Average
# 998             Search Party     5.6            Poor
# 999               Nine Lives     5.3            Poor
#
# [1000 rows x 3 columns]

# %% [markdown]
# 18) Create a custom function to score movies based on:
# i) Apply row['Rating'] * 10 + row['Revenue (Millions)'] as High score
# Apply a function to dataset to assign the score

# %%
def calculate_high_score(row):
    return (row['Rating'] * 10) + row['Revenue (Millions)']


df['High_Score'] = df.apply(calculate_high_score, axis=1)


scored_movies = df.sort_values(by='High_Score', ascending=False)

print(scored_movies[['Movie_Title', 'Rating', 'Revenue (Millions)', 'High_Score']])
# Out:
#                                     Movie_Title  Rating  Revenue (Millions)  \
# 50   Star Wars: Episode VII - The Force Awakens     8.1              936.63
# 87                                       Avatar     7.8              760.51
# 85                               Jurassic World     7.0              652.18
# 76                                 The Avengers     8.1              623.28
# 54                              The Dark Knight     9.0              533.32
# ..                                          ...     ...                 ...
# 27                                   Dead Awake     4.7                0.01
# 936        The Human Centipede (First Sequence)     4.4                0.18
# 237                    The Disappointments Room     3.9                2.41
# 871                        Dragonball Evolution     2.7                9.35
# 829                              Disaster Movie     1.9               14.17
#
#      High_Score
# 50      1017.63
# 87       838.51
# ...
